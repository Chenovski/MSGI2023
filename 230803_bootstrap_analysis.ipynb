# %% [markdown]
# File created by Jinghao Chen (jinghc2@uci.edu).

# %%
import numpy as np
import mptools as mp
import matplotlib.pyplot as plt

# %%
ThetaRaw = mp.combTheta('data/theta230808bootstrap',1,10)

# %%
ThetaRaw.shape
# Out:
# (607, 272)

# %%
Theta, mean, std, _, _ = mp.empiricalRule(ThetaRaw,.68)

# %%
fig, ax = plt.subplots(figsize=(4,3))

vp = ax.violinplot([Theta[:,1],Theta[:,2]], [2, 4], widths=1.5,showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.6)
ax.errorbar([2, 4], mean[1:3], std[1:3], fmt='o', linewidth=2, capsize=3, color = 'black')
ax.set_xticks([2,4])
ax.set_xticklabels(['$C_c$','$C_r$'])
ax.xaxis.grid(False)
ax.yaxis.grid(linestyle='--')
ax.set(xlim=(0, 6))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,3))

vp = ax.violinplot(Theta[:,0], [3], widths=1.5,showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.6)
ax.errorbar([3], mean[0], std[0], fmt='o', linewidth=2, capsize=3, color = 'black')
ax.set_xticks([3])
ax.set_xticklabels(['$\\bar{\\tau}/\\tau_{max}$'])
ax.xaxis.grid(False)
ax.yaxis.grid(linestyle='--')
ax.set(xlim=(0, 6))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,3))

vp = ax.violinplot([Theta[:,0], Theta[:,1],Theta[:,2]], [2, 4, 6], widths=1.5,showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.6)
ax.errorbar([2, 4, 6], mean[0:3], std[0:3], fmt='o', linewidth=2, capsize=3, color = 'black')
ax.set_xticks([2,4,6])
ax.set_xticklabels(['$\\bar{\\tau}/\\tau_{max}$','$C_c$','$C_r$'])
ax.xaxis.grid(False)
ax.yaxis.grid(linestyle='--')
ax.set(xlim=(0, 8),ylim=(0,.5))

plt.show()

# %%
fig, ax = plt.subplots(figsize=(4,3))

vp = ax.violinplot(Theta[:,3], [3], widths=1.5,showextrema=False)
# styling:
for body in vp['bodies']:
    body.set_alpha(0.6)
ax.errorbar([3], mean[3], std[3], fmt='o', linewidth=2, capsize=3, color = 'black')
ax.set_xticks([3])
ax.set_xticklabels(['$\\varepsilon_i$'])
ax.xaxis.grid(False)
ax.yaxis.grid(linestyle='--')
ax.set(xlim=(0, 6))

plt.show()
